# %%
using Plots
using PyCall
np = pyimport("numpy")
;

# %%
m = 1420   
c = 0.35    
A = 2.42    
f = 0.01    
C = np.pi*(14*25.4 + 2*(60/100)*225)
rd = C/(2*np.pi)/1000

g= 9.81
rho = 1.23

v = np.linspace(0, 250/3.6, 25)
Ft = m*g*f
Fw = 1/2*rho*A*c*v.^2
F_all = Ft .+ Fw
plot(v*3.6, F_all)
