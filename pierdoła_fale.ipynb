# %%
import matplotlib.pyplot as plt
from numpy import *


x=[0, 1.6, 2.4, 3.4, 4.2, 5.0, 5.8]
v=[9, 2, 1.4, 1, 3.4, 8, 7.5]




fig = plt.figure(figsize = (20,15) , dpi=80)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.yaxis.grid(True)
ax.set_axisbelow(True)
