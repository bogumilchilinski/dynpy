# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
name = 'ALIOR-BANK'

# %%
df = pd.read_html('https://www.biznesradar.pl/raporty-finansowe-bilans/'+name+',Q')[2].drop([
                                                                0,7,9,12,20,22,24,25,26,27,28,29,30]).set_index('Unnamed: 0')
shares = pd.read_html('https://www.biznesradar.pl/wskazniki-wartosci-rynkowej/'+name)[0].drop([0,2,3,4,5,6,7,8,9]).set_index('Unnamed: 0') 
zis =  pd.read_html('https://www.biznesradar.pl/raporty-finansowe-rachunek-zyskow-i-strat/'+name+',Q')[2].drop([
                                                                                0,1,8,9,10,11,14,15,16,18,20]).set_index('Unnamed: 0')


del df["Unnamed: "+str(len(df.columns))]  
del shares["Unnamed: "+str(len(shares.columns))] 
del zis["Unnamed: "+str(len(zis.columns))]

df = df.drop(df.columns[0:4],axis=1)
shares = shares.drop(shares.columns[0:(len(shares.columns)-len(df.columns))]   ,axis=1)
zis = zis.drop(zis.columns[0:(len(zis.columns)-len(df.columns))]   ,axis=1)
df.columns = df.columns.str.slice(start=2, stop=7)
zis.columns = shares.columns = df.columns


for i in range(len(df.columns)):
    df[str(df.columns[i])] = df[str(df.columns[i])].str.replace('(k/k).*','')
    df[str(df.columns[i])] = df[str(df.columns[i])].str.replace('(r/r).*','')
    zis[str(zis.columns[i])] = zis[str(zis.columns[i])].str.replace('(k/k).*','')
    zis[str(zis.columns[i])] = zis[str(zis.columns[i])].str.replace('(r/r).*','')
    
    df[str(df.columns[i])] = df[str(df.columns[i])].str.replace(' ','')
    shares[str(shares.columns[i])] = shares[str(shares.columns[i])].str.replace(' ','')
    zis[str(zis.columns[i])] = zis[str(zis.columns[i])].str.replace(' ','')
    
df = df.apply(pd.to_numeric, errors='ignore')
shares = shares.apply(pd.to_numeric, errors='ignore')
zis = zis.apply(pd.to_numeric, errors='ignore')
df
# Out:
#                                                        13/Q1     13/Q2  \
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi              728540    721980
# Należności od banków                                  137511    169520
# Aktywa finansowe przeznaczone do obrotu               214952    265384
# Pochodne instrumenty zabezpieczające                       0       476
# Należności od klientów                              15619367  17369735
# Inwestycyjne aktywa finansowe                        3259304   3446706
# Wartości niematerialne                                157627    167406
# Rzeczowy majątek trwały                               207915    206866
# Aktywa z tytułu odroczonego podatku dochodowego...    138063    129494
# Aktywa razem                                        20875108  22822205
# Zobowiązania wobec banku centralnego                       0         0
# Zobowiązania wobec banków                                  0         0
# Pochodne instrumenty zabezpieczające                       0     11300
# Zobowiązania finansowe przeznaczone do obrotu         146274    156717
# Zobowiązania wobec klientów                         17642932  19590714
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0
# Zobowiązania z tytułu bieżącego podatku dochodo...       269      2761
# Zobowiązania razem                                  18865157  20758704
# Kapitały razem                                       2009951   2063501
# Pasywa razem                                        20875108  22822205
#
#                                                        13/Q3     13/Q4  \
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi              755303   1067227
# Należności od banków                                  181811    254199
# Aktywa finansowe przeznaczone do obrotu               234261    243291
# Pochodne instrumenty zabezpieczające                    3463     12099
# Należności od klientów                              18149534  19657900
# Inwestycyjne aktywa finansowe                        2929182   3388525
# Wartości niematerialne                                169044    188050
# Rzeczowy majątek trwały                               206227    215121
# Aktywa z tytułu odroczonego podatku dochodowego...    129576    143793
# Aktywa razem                                        23120144  25549871
# Zobowiązania wobec banku centralnego                       0         0
# Zobowiązania wobec banków                                  0         0
# Pochodne instrumenty zabezpieczające                    5040         0
# Zobowiązania finansowe przeznaczone do obrotu         153753    184090
# Zobowiązania wobec klientów                         20084391  21660435
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0
# Zobowiązania z tytułu bieżącego podatku dochodo...       187     31949
# Zobowiązania razem                                  21051123  23365139
# Kapitały razem                                       2069021   2184732
# Pasywa razem                                        23120144  25549871
#
#                                                        14/Q1     14/Q2  \
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi             1077576   1057413
# Należności od banków                                  278448    305948
# Aktywa finansowe przeznaczone do obrotu               207564    284808
# Pochodne instrumenty zabezpieczające                   20553     15671
# Należności od klientów                              20935596  21882525
# Inwestycyjne aktywa finansowe                        3172488   2784204
# Wartości niematerialne                                187784    190006
# Rzeczowy majątek trwały                               208322    204248
# Aktywa z tytułu odroczonego podatku dochodowego...    146951    145169
# Aktywa razem                                        26517620  27124461
# Zobowiązania wobec banku centralnego                       0         0
# Zobowiązania wobec banków                                  0         0
# Pochodne instrumenty zabezpieczające                       0         0
# Zobowiązania finansowe przeznaczone do obrotu         177527    225988
# Zobowiązania wobec klientów                         22527684  22982887
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0
# Zobowiązania z tytułu bieżącego podatku dochodo...         0     18681
# Zobowiązania razem                                  23799828  24302008
# Kapitały razem                                       2717792   2822453
# Pasywa razem                                        26517620  27124461
#
#                                                        14/Q3       14/Q4  \
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi             1018716   1158440.0
# Należności od banków                                  297497    449378.0
# Aktywa finansowe przeznaczone do obrotu               420848    476821.0
# Pochodne instrumenty zabezpieczające                   53036     80205.0
# Należności od klientów                              22789454  23647990.0
# Inwestycyjne aktywa finansowe                        3799310   2652126.0
# Wartości niematerialne                                208933    215564.0
# Rzeczowy majątek trwały                               195899    191835.0
# Aktywa z tytułu odroczonego podatku dochodowego...    127900    147849.0
# Aktywa razem                                        29156450  30167568.0
# Zobowiązania wobec banku centralnego                       0         NaN
# Zobowiązania wobec banków                                  0   1049162.0
# Pochodne instrumenty zabezpieczające                       0      4777.0
# Zobowiązania finansowe przeznaczone do obrotu         296221    349033.0
# Zobowiązania wobec klientów                         24549799  24427988.0
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0.0
# Zobowiązania z tytułu bieżącego podatku dochodo...         0     24553.0
# Zobowiązania razem                                  26237916  27152492.0
# Kapitały razem                                       2918534   3015076.0
# Pasywa razem                                        29156450  30167568.0
#
#                                                        15/Q1     15/Q2  ...  \
# Unnamed: 0                                                              ...
# Gotówka i operacje z bankami centralnymi             1377659   1814603  ...
# Należności od banków                                  319822    502779  ...
# Aktywa finansowe przeznaczone do obrotu               525101    427473  ...
# Pochodne instrumenty zabezpieczające                  119971     49445  ...
# Należności od klientów                              27410671  28344652  ...
# Inwestycyjne aktywa finansowe                        2494144   2713708  ...
# Wartości niematerialne                                354399    357654  ...
# Rzeczowy majątek trwały                               187521    184272  ...
# Aktywa z tytułu odroczonego podatku dochodowego...    204514    228238  ...
# Aktywa razem                                        34886136  36466760  ...
# Zobowiązania wobec banku centralnego                       0         0  ...
# Zobowiązania wobec banków                            1853647   1600556  ...
# Pochodne instrumenty zabezpieczające                       0     10887  ...
# Zobowiązania finansowe przeznaczone do obrotu         390026    324028  ...
# Zobowiązania wobec klientów                         27799851  29774617  ...
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0  ...
# Zobowiązania z tytułu bieżącego podatku dochodo...     18633     15666  ...
# Zobowiązania razem                                  31564134  33121539  ...
# Kapitały razem                                       3322002   3345221  ...
# Pasywa razem                                        34886136  36466760  ...
#
#                                                        18/Q2     18/Q3  \
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi             
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0
# Zobowiązania z tytułu bieżącego podatku dochodo...     94905     10167
# Zobowiązania razem                                  69976769  69689921
# Kapitały razem                                       6759065   6822312
# Pasywa razem                                        76735834  76512233
#
#                                                        20/Q2     20/Q3
# Unnamed: 0
# Gotówka i operacje z bankami centralnymi             1128515   1636919
# Należności od banków                                  290545    330542
# Aktywa finansowe przeznaczone do obrotu             16756828  15062147
# Pochodne instrumenty zabezpieczające                  379652    367017
# Należności od klientów                              55703480  55995884
# Inwestycyjne aktywa finansowe                              0         0
# Wartości niematerialne                                507747    461424
# Rzeczowy majątek trwały                               713310    700119
# Aktywa z tytułu odroczonego podatku dochodowego...   1223388   1222493
# Aktywa razem                                        77671909  77717339
# Zobowiązania wobec banku centralnego                       0         0
# Zobowiązania wobec banków                             967438   1063235
# Pochodne instrumenty zabezpieczające                   89690     88817
# Zobowiązania finansowe przeznaczone do obrotu         516362    493324
# Zobowiązania wobec klientów                         65865441  65868133
# Zobowiązania z tytułu emisji dłużnych pap. wart.           0         0
# Zobowiązania z tytułu bieżącego podatku dochodo...      1352      1899
# Zobowiązania razem                                  71304558  71251663
# Kapitały razem                                       6367351   6465676
# Pasywa razem                                        77671909  77717339
#
# [20 rows x 31 columns]

# %%
class Balance:
    def __init__(self , df):
        self.time = df.columns
        self.shares = shares.iloc[0]
        self.year = [ self.time[i] for i in range(3,len(self.time),4)]
        self.year = np.append(self.year , '20/Q4')
        self.revenue = zis.iloc[0] + zis.iloc[3]
        self.net_profit = zis.iloc[10]
        self.Last4_revenue = [ np.sum(self.revenue[i-4:i]) for i in range(4,len(self.shares)+1) ]
        self.Last4_profit = [ np.sum(self.net_profit[i-4:i]) for i in range(4,len(self.shares)+1) ]
        self.Revenue_year = [ np.sum(self.revenue[i:i+4]) for i in range(0,len(self.shares),4) ]
        self.Gross_profit = zis.iloc[9]
        self.credit_reserves = zis.iloc[6]
        self.client_receivables = df.iloc[4]
        self.client_debt = df.iloc[14]
        
        self.Equity = df.iloc[18]
        self.cash = df.iloc[0]
        self.Assets_total = df.iloc[9]
        self.Assets_year_mean = [ np.mean(self.Assets_total[i:i+4]) for i in range(0,len(self.shares),4) ]
        
        self.ROE = self.Last4_profit/self.Equity[3:len(self.Equity)] 
        self.beta = self.Equity[3:len(self.Equity)]/self.Last4_revenue
        self.Assets_productivity = [ self.Revenue_year[i]/self.Assets_year_mean[i]*100 for i in range(0,len(self.Revenue_year))]
        
    def equity(self):
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(311)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.bar(self.time, self.Equity/self.shares*1000, 
                label='equity/share ='"$"+str(round(self.Equity[len(self.shares)-1]/self.shares[len(self.shares)-1]*1000,2))+"$")
        plt.plot(self.time, self.cash/self.shares*1000 , color='green', linewidth = 3, 
                 label='cash/share ='"$"+str(round(self.cash[len(self.shares)-1]/self.shares[len(self.shares)-1]*1000,2))+"$")
        
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.legend(loc='best' , fontsize = 12 )
        self.ax = plt.subplot(312)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.bar(self.time[3:len(self.shares)], self.ROE*100, color='darkgreen')
        self.ax.set_title('ROE')
        self.ax.set_ylabel('[%]')
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.tight_layout(pad=3)
        self.ax = plt.subplot(313)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.plot(self.time[3:len(self.shares)], self.beta[3:len(self.shares)]*self.ROE*100 )
        self.ax.set_title('ROE*BETA')
        self.ax.set_ylabel('[%]')
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.tight_layout(pad=3)
        
        
    def cover(self):
        self.fig = plt.figure(figsize = (20,18) , dpi=80)
        self.ax = plt.subplot(211)
        self.ax.spines["top"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.bar(self.time, self.client_receivables/self.client_debt, label='clients receives/debt')
        
        # plt.plot(self.time, self.cash/np.absolute(self.credit_reserves), label = 'cash / credit reserves')
        # plt.plot(self.time, self.client_receivables/np.absolute(self.credit_reserves), label= ' receives / credit reserves')
        plt.xticks(rotation = 50)        
        self.ax.legend(loc='best')

# %%
fin = Balance(df)
display(fin.equity())
display(fin.cover())
# Out:
# None
# None
