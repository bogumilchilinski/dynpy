# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
ticker = 'TM'
name = 'toyota'

# %%
rev = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/revenue' ,index_col=0)[1].T
production_costs = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/cost-goods-sold' ,index_col=0)[1].T
cash_on_hand = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/cash-on-hand' ,index_col=0)[1].T
equity = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/total-share-holder-equity' ,index_col=0)[1].T
net_profit = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/net-income' ,index_col=0)[1].T
shares = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/shares-outstanding' ,index_col=0)[1].T
assets_total = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/total-assets' ,index_col=0)[1].T
current_assets = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/total-current-assets' ,index_col=0)[1].T
current_debt = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/total-current-liabilities' ,index_col=0)[1].T
supplies = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/inventory' ,index_col=0)[1].T
long_loans = pd.read_html('https://www.macrotrends.net/stocks/charts/'+ticker+'/'+name+'/long-term-debt' ,index_col=0)[1].T

for i in range(len(rev.columns)):
    rev[str(rev.columns[i])] = rev[str(rev.columns[i])].str.replace('$','').str.replace(',','')
    production_costs[str(production_costs.columns[i])] = production_costs[str(production_costs.columns[i])].str.replace('$','').str.replace(',','')
    net_profit[str(net_profit.columns[i])] = net_profit[str(net_profit.columns[i])].str.replace('$','').str.replace(',','')
    cash_on_hand[str(cash_on_hand.columns[i])] = cash_on_hand[str(cash_on_hand.columns[i])].str.replace('$','').str.replace(',','')
    equity[str(equity.columns[i])] = equity[str(equity.columns[i])].str.replace('$','').str.replace(',','')
    assets_total[str(assets_total.columns[i])] = assets_total[str(assets_total.columns[i])].str.replace('$','').str.replace(',','')
    current_assets[str(current_assets.columns[i])] = current_assets[str(current_assets.columns[i])].str.replace('$','').str.replace(',','')
    current_debt[str(current_debt.columns[i])] = current_debt[str(current_debt.columns[i])].str.replace('$','').str.replace(',','')
    supplies[str(supplies.columns[i])] = supplies[str(supplies.columns[i])].str.replace('$','').str.replace(',','')
    long_loans[str(long_loans.columns[i])] = long_loans[str(long_loans.columns[i])].str.replace('$','').str.replace(',','')
    
rev = rev.apply(pd.to_numeric, errors='ignore')
production_costs = production_costs.apply(pd.to_numeric, errors='ignore')
net_profit = net_profit.apply(pd.to_numeric, errors='ignore')
shares = shares.apply(pd.to_numeric, errors='ignore') 
cash_on_hand = cash_on_hand.apply(pd.to_numeric, errors='ignore') 
equity = equity.apply(pd.to_numeric, errors='ignore') 
assets_total = assets_total.apply(pd.to_numeric, errors='ignore') 
current_assets = current_assets.apply(pd.to_numeric, errors='ignore') 
current_debt = current_debt.apply(pd.to_numeric, errors='ignore') 
supplies = supplies.apply(pd.to_numeric, errors='ignore')
long_loans = long_loans.apply(pd.to_numeric, errors='ignore')

df = pd.concat([rev, production_costs, net_profit, shares, cash_on_hand,
                equity, assets_total, current_assets, current_debt, supplies, long_loans], ignore_index=False) 
df.columns = df.columns.str.slice(start=2 , stop=7)
columns = df.columns.tolist()
columns = columns[::-1]
df = df[columns]
df = df.drop(df.columns[0:13],axis=1)
df
# Out:
#                                                        09-03     09-06  \
# Toyota Quarterly Revenue(Millions of US $).1         40139.0   39955.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   39915.0   37005.0
# Toyota Quarterly Net Income(Millions of US $).1      -7312.0    -811.0
# Toyota Quarterly Shares Outstanding(Millions of...    1566.0    1560.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    30386.0   32937.0
# Toyota Quarterly Share Holder Equity(Millions o...  102425.0  110425.0
# Toyota Quarterly Total Assets(Millions of US $).1   295857.0  306265.0
# Toyota Quarterly Total Current Assets(Millions ...  115025.0  121924.0
# Toyota Quarterly Total Current Liabilities(Mill...  107801.0  110594.0
# Toyota Quarterly Inventory(Millions of US $).1       14857.0   15457.0
# Toyota Quarterly Long Term Debt(Millions of US ...   64150.0   68383.0
#
#                                                        09-09     09-12  \
# Toyota Quarterly Revenue(Millions of US $).1         50344.0   57469.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   44608.0   49521.0
# Toyota Quarterly Net Income(Millions of US $).1        242.0    1664.0
# Toyota Quarterly Shares Outstanding(Millions of...    1513.0    1570.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    39260.0   42154.0
# Toyota Quarterly Share Holder Equity(Millions o...  116376.0  115858.0
# Toyota Quarterly Total Assets(Millions of US $).1   316359.0  320874.0
# Toyota Quarterly Total Current Assets(Millions ...  128598.0  134322.0
# Toyota Quarterly Total Current Liabilities(Mill...  106853.0  113078.0
# Toyota Quarterly Inventory(Millions of US $).1       16193.0   15381.0
# Toyota Quarterly Long Term Debt(Millions of US ...   76740.0   75085.0
#
#                                                        10-03     10-06  \
# Toyota Quarterly Revenue(Millions of US $).1         55919.0   55061.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   48185.0   46814.0
# Toyota Quarterly Net Income(Millions of US $).1       1156.0    2153.0
# Toyota Quarterly Shares Outstanding(Millions of...    1563.0    1560.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    43547.0   46248.0
# Toyota Quarterly Share Holder Equity(Millions o...  117481.0  121432.0
# Toyota Quarterly Total Assets(Millions of US $).1   326196.0  336591.0
# Toyota Quarterly Total Current Assets(Millions ...  140516.0  144679.0
# Toyota Quarterly Total Current Liabilities(Mill...  114856.0  118066.0
# Toyota Quarterly Inventory(Millions of US $).1       15288.0   15963.0
# Toyota Quarterly Long Term Debt(Millions of US ...   75402.0   78300.0
#
#                                                        10-09     10-12  \
# Toyota Quarterly Revenue(Millions of US $).1         57345.0   57346.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   50603.0   50251.0
# Toyota Quarterly Net Income(Millions of US $).1       1177.0    1149.0
# Toyota Quarterly Shares Outstanding(Millions of...    1549.0    1553.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    46906.0   43159.0
# Toyota Quarterly Share Holder Equity(Millions o...  128717.0  132628.0
# Toyota Quarterly Total Assets(Millions of US $).1   351202.0  358748.0
# Toyota Quarterly Total Current Assets(Millions ...  145472.0  144836.0
# Toyota Quarterly Total Current Liabilities(Mill...  119388.0  122801.0
# Toyota Quarterly Inventory(Millions of US $).1       16457.0   16856.0
# Toyota Quarterly Long Term Debt(Millions of US ...   83241.0   82293.0
#
#                                                        11-03     11-06  ...  \
# Toyota Quarterly Revenue(Millions of US $).1         58675.0   42624.0  ...
# Toyota Quarterly Cost of Goods Sold(Millions of...   52155.0   38856.0  ...
# Toyota Quarterly Net Income(Millions of US $).1        430.0      14.0  ...
# Toyota Quarterly Shares Outstanding(Millions of...    1563.0    1556.0  ...
# Toyota Quarterly Cash on Hand(Millions of US $).1    42214.0   43231.0  ...
# Toyota Quarterly Share Holder Equity(Millions o...  131329.0  133868.0  ...
# Toyota Quarterly Total Assets(Millions of US $).1   358607.0  362751.0  ...
# Toyota Quarterly Total Current Assets(Millions ...  142270.0  143813.0  ...
# Toyota Quarterly Total Current Liabilities(Mill...  129778.0  133628.0  ...
# Toyota Quarterly Inventory(Millions of US $).1       15685.0   17141.0  ...
# Toyota Quarterly Long Term Debt(Millions of US ...   77561.0   74506.0  ...
#
#                                                        18-09     18-12  \
# Toyota Quarterly Revenue(Millions of US $).1         65801.0   69434.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   53964.0   56499.0
# Toyota Quarterly Net Income(Millions of US $).1       5266.0    1610.0
# Toyota Quarterly Shares Outstanding(Millions of...    1461.0    1456.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    52830.0   46859.0
# Toyota Quarterly Share Holder Equity(Millions o...  181922.0  176052.0
# Toyota Quarterly Total Assets(Millions of US $).1   472644.0  454665.0
# Toyota Quarterly Total Current Assets(Millions ...  166734.0  158342.0
# Toyota Quarterly Total Current Liabilities(Mill...  161837.0  158164.0
# Toyota Quarterly Inventory(Millions of US $).1       23252.0   22741.0
# Toyota Quarterly Long Term Debt(Millions of US ...   99580.0   92859.0
#
#                                                        19-03     19-06  \
# Toyota Quarterly Revenue(Millions of US $).1         69059.0   69579.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   57482.0   56512.0
# Toyota Quarterly Net Income(Millions of US $).1       4023.0    6215.0
# Toyota Quarterly Shares Outstanding(Millions of...    1459.0    1416.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    52454.0   56427.0
# Toyota Quarterly Share Holder Equity(Millions o...  180604.0  184194.0
# Toyota Quarterly Total Assets(Millions of US $).1   467433.0  474269.0
# Toyota Quarterly Total Current Assets(Millions ...  169913.0  175508.0
# Toyota Quarterly Total Current Liabilities(Mill...  164042.0  162906.0
# Toyota Quarterly Inventory(Millions of US $).1       23908.0   24917.0
# Toyota Quarterly Long Term Debt(Millions of US ...   94959.0   95997.0
#
#                                                        19-09     19-12  \
# Toyota Quarterly Revenue(Millions of US $).1         71047.0   69410.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   58445.0   56568.0
# Toyota Quarterly Net Income(Millions of US $).1       5506.0    6790.0
# Toyota Quarterly Shares Outstanding(Millions of...    1426.0    1416.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    57575.0   55595.0
# Toyota Quarterly Share Holder Equity(Millions o...  190655.0  193493.0
# Toyota Quarterly Total Assets(Millions of US $).1   485833.0  494970.0
# Toyota Quarterly Total Current Assets(Millions ...  176485.0  177103.0
# Toyota Quarterly Total Current Liabilities(Mill...  166770.0  166814.0
# Toyota Quarterly Inventory(Millions of US $).1       23966.0   22387.0
# Toyota Quarterly Long Term Debt(Millions of US ...   96164.0  100602.0
#
#                                                        20-03     20-06  \
# Toyota Quarterly Revenue(Millions of US $).1         65319.0   42787.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   54081.0   37678.0
# Toyota Quarterly Net Income(Millions of US $).1        590.0    1477.0
# Toyota Quarterly Shares Outstanding(Millions of...    1423.0    1397.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    52417.0   81488.0
# Toyota Quarterly Share Holder Equity(Millions o...  190787.0  200021.0
# Toyota Quarterly Total Assets(Millions of US $).1   484660.0  520024.0
# Toyota Quarterly Total Current Assets(Millions ...  171511.0  190117.0
# Toyota Quarterly Total Current Liabilities(Mill...  164702.0  175837.0
# Toyota Quarterly Inventory(Millions of US $).1       22401.0   22778.0
# Toyota Quarterly Long Term Debt(Millions of US ...   98375.0  116847.0
#
#                                                        20-09     20-12
# Toyota Quarterly Revenue(Millions of US $).1         63680.0   78240.0
# Toyota Quarterly Cost of Goods Sold(Millions of...   52887.0   62336.0
# Toyota Quarterly Net Income(Millions of US $).1       4423.0    8051.0
# Toyota Quarterly Shares Outstanding(Millions of...    1397.0    1416.0
# Toyota Quarterly Cash on Hand(Millions of US $).1    81536.0   83383.0
# Toyota Quarterly Share Holder Equity(Millions o...  204883.0  217278.0
# Toyota Quarterly Total Assets(Millions of US $).1   530948.0  556899.0
# Toyota Quarterly Total Current Assets(Millions ...  197999.0  208097.0
# Toyota Quarterly Total Current Liabilities(Mill...  185585.0  197858.0
# Toyota Quarterly Inventory(Millions of US $).1       25468.0   25151.0
# Toyota Quarterly Long Term Debt(Millions of US ...  114228.0  114658.0
#
# [11 rows x 48 columns]

# %%
class ZIS:
    def __init__(self , df):
        self.time = df.columns
        self.shares = df.iloc[2]
        self.year = [ self.time[i] for i in range(3,len(self.time),4)]
        #self.year = np.append(self.year , '20/Q4')
        self.revenue = df.iloc[0]
        self.Production_cost = df.iloc[1]
        self.net_profit = df.iloc[2]
        self.Last4_profit = []
        self.Last4_revenue = []
        self.Revenue_year = [ np.sum(self.revenue[i:i+4]) for i in range(0,len(self.shares),4) ]
        self.Profit_year = [np.sum(self.net_profit[i:i+4]) for i in range(0,len(self.shares),4) ]
        self.Last4_profit = [ np.sum(self.net_profit[i-4:i]) for i in range(4,len(self.shares)+1) ]
        self.Last4_revenue = [ np.sum(self.revenue[i-4:i]) for i in range(4,len(self.shares)+1) ]
            
        self.Current_assets = df.iloc[7]
        self.cash = df.iloc[4]
        self.Assets_total = df.iloc[6]
        self.Short_debt = df.iloc[8]
        self.Supplies = df.iloc[9]
        self.Loans = df.iloc[10]
        
        self.Assets_year_mean = [ np.mean(self.Assets_total[i:i+4]) for i in range(0,len(self.shares),4) ]
        self.Supplies_year_mean = [ np.mean(self.Supplies[i:i+4]) for i in range(0,len(self.shares),4) ]
        self.Equity = df.iloc[5]
        self.beta = self.Equity[3:len(self.Equity)]/self.Last4_revenue
        self.ROE = self.Last4_profit/self.Equity[3:len(self.Equity)]
        self.Assets_productivity = [ self.Revenue_year[i]/self.Assets_year_mean[i]*100 for i in range(0,len(self.Revenue_year))]
        self.Supply_productivity = [ self.Profit_year[i]/self.Supplies_year_mean[i]*100 for i in range(0,len(self.Revenue_year))]
        self.Current_ratio = self.Current_assets/self.Short_debt
        self.Cash_cover = self.cash/self.Short_debt
        self.SupplyCover = self.Supplies/self.Short_debt
        self.ROI = (self.cash+self.Supplies)/self.Loans
        
    def equity(self):
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(311)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.bar(self.time, self.Equity/self.shares*1000, 
                label='equity/share ='"$"+str(round(self.Equity[len(self.shares)-1]/self.shares[len(self.shares)-1],2))+"$")
        plt.plot(self.time, self.cash/self.shares*1000 , color='green', linewidth = 3, 
                 label='cash/share ='"$"+str(round(self.cash[len(self.shares)-1]/self.shares[len(self.shares)-1],2))+"$")
        
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.legend(loc='best' , fontsize = 12 )
        self.ax = plt.subplot(312)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.bar(self.time[3:len(self.shares)], self.ROE*100, color='darkgreen')
        self.ax.set_title('ROE')
        self.ax.set_ylabel('[%]')
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.tight_layout(pad=3)
        self.ax = plt.subplot(313)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        
        plt.plot(self.time[3:len(self.shares)], self.beta[3:len(self.shares)]*self.ROE*100 )
        self.ax.set_title('ROE*BETA')
        self.ax.set_ylabel('[%]')
        plt.xticks(rotation = 50 , fontsize = 12)
        plt.tight_layout(pad=3)
        
    def Assets(self):
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(211)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        self.ax.set_title('Assets' , fontsize = 20)
        plt.bar(self.time, self.Assets_total/1000, label='Total Assets')
        plt.plot(self.time, self.Current_assets/1000, color='firebrick',label='Current Assets')
        self.ax.set_ylabel('w mln')
        plt.xticks(rotation=50)
        self.ax = plt.subplot(212)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.plot(self.year , self.Assets_productivity, label='Assets productivity = revenue/assets')
        plt.plot(self.year , self.Supply_productivity, label = 'Supplies productivity = profit/supplies')
        plt.legend(loc='best')
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(211)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.plot(self.time , (self.Current_assets-self.Short_debt)/self.Assets_total*100, label='(Current assets-Short debt)/Total Assets')
        plt.legend(loc='best' , fontsize = 12 )
        plt.xticks(rotation=50)
        
    def Cover(self):
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(211)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        self.ax.set_title('Liquidity' , fontsize=20)
        plt.plot(self.time, self.Current_ratio, label='Current ratio')
        plt.plot(self.time, self.SupplyCover, label='Supply cover')
        plt.plot(self.time, self.Cash_cover, label='Cash cover')
        plt.legend(loc='best')
        plt.xticks(rotation = 50)
        self.ax = plt.subplot(212)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.bar(self.time, self.Supplies/self.Production_cost, label= 'Supply/Production Costs')
        plt.plot(self.time, self.ROI, label='ROI= (Cash+supplies)/Loans')
        # plt.plot(self.time, self.Loans)
        plt.xticks(rotation = 50)
        plt.legend(loc='best')
        
    def Flow(self):
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(211)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        self.ax.set_title('Flow' , fontsize=20)
        # plt.plot(self.time , self.FreeCashFlow/self.shares*1000, marker='o', label='Free Cash Flow')  
        plt.legend(loc='best' , fontsize = 15)
        plt.xticks(rotation = 50)
        self.ax = plt.subplot(212)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        # plt.plot(self.time , self.operating_financial_score/self.shares*100, marker='o', label='Operating and financial score')
        plt.legend(loc='best' , fontsize = 15)
        plt.xticks(rotation = 50)
        
        self.fig = plt.figure(figsize = (20,15) , dpi=80)
        self.ax = plt.subplot(311)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.plot(self.time, self.Supplies/self.Production_cost*100, label='Supplies/Production cost [%]')
        plt.plot(self.time , self.Short_debt/self.Production_cost*100, label='Short debt/Production cost [%]')
        plt.xticks(rotation=50)
        plt.legend(loc='best' , fontsize=15)
        self.ax = plt.subplot(312)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.plot(self.time, self.Supplies/self.Sell_profit*100, label='Supplies/Sell profit %')
        plt.xticks(rotation=50)
        plt.legend(loc='best' , fontsize=15)
        self.ax = plt.subplot(313)
        self.ax.spines["top"].set_visible(False)
        self.ax.spines["right"].set_visible(False)
        self.ax.yaxis.grid(True)
        self.ax.set_axisbelow(True)
        plt.plot(self.time, self.Amortization/self.Supplies*100, label='Amortization/Supplies')
        plt.legend(loc='best' , fontsize=15)
        plt.xticks(rotation = 50)

# %%
fin = ZIS(df) 
display(fin.equity())
display(fin.Assets())
display(fin.Cover())
# display(fin.Flow)
# Out:
# None
# None
# None
