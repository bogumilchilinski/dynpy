# %%
from bs4 import BeautifulSoup as bs4 
import requests
import pandas as pd

# %%
df = pd.read_html('https://www.biznesradar.pl/wskazniki-rentownosci/IZOSTAL')[2]
df
# Out:
#                         Unnamed: 0     2007/Q4  (gru 07)  \
# 0                              ROE  17.24%~sektor 13.83%
# 1                              ROA    7.72%~sektor 7.60%
# 2         Marża zysku operacyjnego    6.13%~sektor 7.68%
# 3                Marża zysku netto    4.98%~sektor 6.32%
# 4         Marża zysku ze sprzedaży    5.09%~sektor 7.02%
# 5               Marża zysku brutto    6.08%~sektor 7.80%
# 6  Marża zysku brutto ze sprzedaży  13.83%~sektor 16.66%
# 7    Rentowność operacyjna aktywów    9.50%~sektor 7.90%
# 8                             ROIC  17.60%~sektor 12.50%
#
#                                2008/Q4  (gru 08)  \
# 0   17.51%~sektor 13.81%r/r +1.57%~sektor -0.11%
# 1   6.80%~sektor 5.12%r/r -11.92%~sektor -32.57%
# 2   7.22%~sektor 6.72%r/r +17.78%~sektor -12.49%
# 3    4.79%~sektor 4.80%r/r -3.82%~sektor -24.19%
# 4    7.17%~sektor 7.56%r/r +40.86%~sektor +7.84%
# 5    5.96%~sektor 6.01%r/r -1.97%~sektor -22.90%
# ...

# %%
r = requests.get('https://www.biznesradar.pl/wskazniki-rentownosci/IZOSTAL')

soup = bs4(r.content)
c = soup.prettify()

display(c)
# Out:
# '<!DOCTYPE html>\n<html dir="ltr" lang="pl">\n <head>\n  <meta charset="utf-8"/>\n  <meta content="width=1024" name="viewport"/>\n  <title>\n   [BR Premium] Notatki ze spotkania wynikowego z zarządem Dekpol - BiznesRadar.pl\n  </title>\n  <meta content="Notatki ze spotkania z zarządem Dekpol poświęconego podsumowaniu wyników za pierwszą połowę 2020 r. które miało miejsce 30 września 2020 r. W trakcie spotkania przedstawiciele spółki omówili wyniki finansowe, przedstawili aktualną..." name="description"/>\n  <link href="/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>\n  <link href="/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>\n  <link href="/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>\n  <link href="/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>\n  <link href="/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>\n  <link href="/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>\n  <link href="/ap
# ...
